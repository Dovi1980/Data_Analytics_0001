# %% [markdown]
# # Data Science - Manipulación de Datos en Python

# %% [markdown]
# ### Ejercicio 2 - Proyecto Final
# ### Alumno: Vdovichenko, Walter
# ### Fecha de entrega: 29/10/2023

# %% [markdown]
# ### Enunciado:
# Realizar una ingesta de datos de un archivo formato .csv utilizando la librería de Pandas
# Para este apartado, deberás poder ingestar un archivo en Jupyter Notebook en un formato de tipo .csv.
# Resulta importante aclarar que, la elección del archivo queda a criterio propio, sin embargo, a continuación se proporciona un link de interés para la descarga gratuita de datasets.
#
# Enlace: https://www.kaggle.com/datasets (opens in a new tab)
#
# ***Importante:** en caso de no disponer de una cuenta en Kaggle, será requerido realizar el registro correspondiente en la página.*

# %% [markdown]
# ###  --------- Inicio ---------

# %%
import pandas as pd

df = pd.read_csv("C:/Users/wvdov/Documents/Cursada/CapacitacionCABA/Manipulacion Datos enPython/!!! Proyecto Final/dataset_eje2/Data.csv", sep=",")

# %%
print(df.shape)
# Out:
# (193, 26)

# %%
df.count()
# Out:
# Código                               193
# Código de barras                     193
# Marca                                193
# Tipo de Chip                         193
# Multichip                            193
# Tipo de Tela                         193
# Tamanho do Display                   193
# Resolução                            193
# Câmera Traseira                      193
# Câmera Frontal                       193
# Filmadora                            193
# Processador                          193
# Memória RAM                          193
# Memória Interna                      193
# Expansivo até?                       193
# Banda                                193
# Conexões                             193
# Alimentação, tipo de bateria         193
# Conteúdo da Embalagem                193
# Garantia do Fornecedor               193
# Dimensões do produto - cm (AxLxP)    193
# Modelo                               193
# Referência do Modelo                 193
# SAC                                  193
# Cor                                  193
# Preço                                193
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 26 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Código                             193 non-null    int64
#  1   Código de barras                   193 non-null    int64
#  2   Marca                              193 non-null    object
#  3   Tipo de Chip                       193 non-null    object
#  4   Multichip                          193 non-null    object
#  5   Tipo de Tela                       193 non-null    object
#  6   Tamanho do Display                 193 non-null    object
#  7   Resolução                          193 non-null    object
#  8   Câmera Traseira                    193 non-null    object
#  9   Câmera Frontal                     193 non-null    object
#  10  Filmadora                          193 non-null    object
#  11  Processador                        193 non-null    object
#  12  Memória RAM                        193 non-null    object
#  13  Memória Interna                    193 non-null    object
#  14  Expansivo até?                     193 non-null    object
#  15  Banda                              193 non-null    object
#  16  Conexões                           193 non-null    object
#  17  Alimentação, tipo de bateria       193 non-null    object
#  18  Conteúdo da Embalagem              193 non-null    object
#  19  Garantia do Fornecedor             193 non-null    object
#  20  Dimensões do produto - cm (AxLxP)  193 non-null    object
#  21  Modelo                             193 non-null    object
#  22  Referência do Modelo               193 non-null    object
#  23  SAC                                193 non-null    object
#  24  Cor                                193 non-null    object
#  25  Preço                              193 non-null    object
# dtypes: int64(2), object(24)
# memory usage: 39.3+ KB

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
print(df.columns)
# Out:
# Index(['Código', 'Código de barras', 'Marca', 'Tipo de Chip', 'Multichip',
#        'Tipo de Tela', 'Tamanho do Display', 'Resolução', 'Câmera Traseira',
#        'Câmera Frontal', 'Filmadora', 'Processador', 'Memória RAM',
#        'Memória Interna', 'Expansivo até?', 'Banda', 'Conexões',
#        'Alimentação, tipo de bateria', 'Conteúdo da Embalagem',
#        'Garantia do Fornecedor', 'Dimensões do produto - cm (AxLxP)', 'Modelo',
#        'Referência do Modelo', 'SAC', 'Cor', 'Preço'],
#       dtype='object')

# %%
columns_to_drop = ['Código','Código de barras','Multichip',
       'Tipo de Tela','Filmadora','Expansivo até?', 'Banda', 'Conexões',
       'Alimentação, tipo de bateria','Garantia do Fornecedor','SAC', 'Cor',]
df.drop(columns_to_drop, axis = "columns", inplace = True)

# %%
print(df.columns)
# Out:
# Index(['Marca', 'Tipo de Chip', 'Tamanho do Display', 'Resolução',
#        'Câmera Traseira', 'Câmera Frontal', 'Processador', 'Memória RAM',
#        'Memória Interna', 'Conteúdo da Embalagem',
#        'Dimensões do produto - cm (AxLxP)', 'Modelo', 'Referência do Modelo',
#        'Preço'],
#       dtype='object')

# %%
print(df.shape)
# Out:
# (193, 14)

# %%
df.head()
# Out:
#       Marca     Tipo de Chip Tamanho do Display           Resolução  \
# 0   Samsung   Nano-SIM (4FF)               6.6"  1080 x 2408 (FHD+)
# 1  Motorola         Nano SIM               6,5"      HD+ (720x1600)
# 2   Samsung   Nano-SIM (4FF)               6.6"  1080 x 2408 (FHD+)
# 3  Motorola  Nano SIM, e-SIM               6,5"      HD+ (720x1600)
# 4  Motorola         Nano SIM               6,5"      HD+ (720x1600)
#
#                                      Câmera Traseira Câmera Frontal  \
# 0                                   50MP + 5MP + 2MP           13MP
# 1  Dupla: Principal de 16MP + Sensor de Profundid...            5MP
# 2                                   50MP + 5MP + 2MP           13MP
# 3            Dupla: Principal de 50MP + Macro de 2MP            8MP
# 4  Dupla: Principal de 16MP + Sensor de Profundid...            5MP
#
#                  Processador      Memória RAM Memória Interna  \
# 0             Octa-Core 2GHz              4GB           128GB
# 1               MediaTek G37              4GB           128GB
# 2             Octa-Core 2GHz              4GB           128GB
# 3  Snapdragon 480+ Octa-Core  4GB + RAM Boost           128GB
# 4               MediaTek G37              4GB           128GB
#
#                                Conteúdo da Embalagem  \
# 0  Aparelho celular, carregador, cabo USB, Extrat...
# 1  1 Smartphone, Kit de manuais, 1 Cabo USB-A/USB...
# 2  Aparelho celular, carregador, cabo USB, Extrat...
# 3  1 Smartphone, Kit de manuais, 1 Cabo USB-A/USB...
# 4  1 Smartphone, Kit de manuais, 1 Cabo USB-A/USB...
#
#   Dimensões do produto - cm (AxLxP)       Modelo Referência do Modelo  \
# 0                   16,7x7,8x0,91cm  SM-A145M/DS  Galaxy A14 4G 128GB
# 1                          18x9x5cm          E22            XT2239-10
# 2                   16,7x7,8x0,91cm     SM-A145M  Galaxy A14 4G 128GB
# 3                          17x8x5cm       PAVU00             XT2335-1
# 4                          18x9x5cm  SM-A145M/DS            XT2239-10
#
#          Preço
# 0    R$ 999,00
# 1    R$ 809,10
# 2  R$ 1.870,79
# 3    R$ 719,00
# 4    R$ 999,00

# %%
df.tail()
# Out:
#         Marca    Tipo de Chip Tamanho do Display           Resolução  \
# 188   Samsung  Nano-SIM (4FF)               6.6"  1080 x 2340 (FHD+)
# 189   Samsung       Nano Chip              6.5''  1080 x 2400 (FHD+)
# 190   Samsung       Nano Chip              6.5''    720 x 1600 (HD+)
# 191  Motorola       Nano Chip               6.4"  2340 x 1080 (FHD+)
# 192  Motorola       Nano Chip              6.6''  1080 x 2408 (FHD+)
#
#             Câmera Traseira Câmera Frontal  \
# 188  50MP + 5MP + 2MP + 2MP            8MP
# 189        50MP + 2MP + 2MP           13MP
# 190       50MP + 12MP + 5MP           32MP
# 191        48MP + 8MP + 5MP           13MP
# 192       50 mp ois + 13 mp          32 mp
#
#                                          Processador Memória RAM  \
# 188                                        Octa-Core         6GB
# 189                                        Octa-Core         6GB
# 190                                 Octa-Core 2.4GHz         2GB
# 191                                 Octa-Core 2.6GHz         6GB
# 192  Dimensity 8020 (2,6 GHz Octa-Core) Mali-G77 MC9         4GB
#
#     Memória Interna                              Conteúdo da Embalagem  \
# 188           128GB  Aparelho celular, carregador, cabo USB, Extrat...
# 189           128GB  Aparelho celular, carregador, cabo USB, Extrat...
# 190            32GB  1 Telefone,1 Capa Protetora,1 Kit De Manuais,1...
# 191           128GB  Aparelho celular, Carregador, Cabo USB, Extrat...
# 192           128GB  Celular. carregador. cabo usb. extrator de chi...
#
#     Dimensões do produto - cm (AxLxP)  \
# 188                  16,1x7,81x0,82cm
# 189                  15,8.x7,4x0,84cm
# 190                 16,42x7,59x0,91cm
# 191                 15,57x7,45x0,79cm
# 192                16.8 x 7.8 x 0.9cm
#
#                                                 Modelo  \
# 188                                      Motorola Edge
# 189                                        SM-G781B/DS
# 190                                     SM-A042MZCPZTO
# 191                                        SM-A032M/DS
# 192  Celular samsung galaxy a04s 64gb dual - sm-a04...
#
#         Referência do Modelo        Preço
# 188      Galaxy A34 5G 128GB  R$ 2.879,00
# 189         Galaxy S20 FE 5G  R$ 2.268,65
# 190          Galaxy A03 Core    R$ 594,15
# 191  Galaxy S21 FE 5G 128 GB    R$ 649,00
# 192      Galaxy A14 5G 128GB    R$ 809,90

# %%
df.describe().T
# Out:
#                                   count unique  \
# Marca                               193      5
# Tipo de Chip                        193      5
# Tamanho do Display                  193      8
# Resolução                           193      8
# Câmera Traseira                     193     21
# Câmera Frontal                      193     10
# Processador                         193     18
# Memória RAM                         193      6
# Memória Interna                     193      4
# Conteúdo da Embalagem               193     12
# Dimensões do produto - cm (AxLxP)   193     21
# Modelo                              193     32
# Referência do Modelo                193     17
# Preço                               193     40
#
#                                                                                  top  \
# Marca                                                                        Samsung
# Tipo de Chip                                                               Nano Chip
# Tamanho do Display                                                             6.5''
# Resolução                                                         1080 x 2408 (FHD+)
# Câmera Traseira                                               50MP + 5MP + 2MP + 2MP
# Câmera Frontal                                                                  32MP
# Processador                                                                Octa-Core
# Memória RAM                                                                      4GB
# Memória Interna                                                                128GB
# Conteúdo da Embalagem              Aparelho celular, carregador, cabo USB, Extrat...
# Dimensões do produto - cm (AxLxP)                                 16.8 x 7.8 x 0.9cm
# Modelo                                                                   SM-A032M/DS
# Referência do Modelo                                                 Galaxy A03 Core
# Preço                                                                      R$ 649,00
#
#                                   freq
# Marca                               88
# Tipo de Chip                       136
# Tamanho do Display                  72
# Resolução                           57
# Câmera Traseira                     22
# Câmera Frontal                      51
# Processador                         45
# Memória RAM                         82
# Memória Interna                    154
# Conteúdo da Embalagem               79
# Dimensões do produto - cm (AxLxP)   26
# Modelo                              14
# Referência do Modelo                28
# Preço                               15

# %%
df['Referência do Modelo'].value_counts().head(10)
# Out:
# Galaxy A03 Core            28
# Galaxy A14 5G 128GB        26
# Galaxy S20 FE 5G           25
# Galaxy A23 5G              25
# Galaxy S21 FE 5G 128 GB    17
# Galaxy A54 5G 128GB        15
# XT2233-1                   13
# Galaxy A34 5G 128GB        12
# XT2239-10                   6
# Galaxy A14 4G 128GB         6
# Name: Referência do Modelo, dtype: int64

# %%
df['Referência do Modelo'].value_counts().head(10).plot(kind = 'bar')
# Out:
# <Axes: >
